# %%
import pandas as pd
import plotly.graph_objects as go
# %pip install nbformat
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
bh = pd.read_csv("../output/AAPL_buyhold.csv")
mac = pd.read_csv("../output/AAPL_crossover_50_200.csv")

# %%
cumMaxHold = bh["Equity"].cummax()
cumMaxCross = mac["Equity"].cummax()

ddHold  = (bh["Equity"]  - cumMaxHold)  / cumMaxHold
ddCross = (mac["Equity"] - cumMaxCross) / cumMaxCross

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=bh["Date"],  y=ddHold * 100,  name="Buy & Hold"))
fig.add_trace(go.Scatter(x=mac["Date"], y=ddCross * 100, name="MA Crossover"))
fig.update_layout(title="AAPL: Drawdown Over Time",
                  xaxis_title="Date", yaxis_title="Drawdown (%)")
fig.show()

# %% [markdown]
# While it isn't suprising that Buy and Hold over the years 2014-2024 way out performed Moving Average Crossover(50, 200), the graph shows us that crossover went up from 100k -> ~226k and then back down to ~123k in mid 2019 where it had its worst drawdown of 45%.
#
# Crossover (50/200) on AAPL 2015-2024 returned ~407% vs buy-and-hold's ~928%, with a deeper max drawdown (~45.6% vs ~38.5%), peaked in Jan 2022 and never recovered while buy-and-hold set new highs through 2024.
#
# This result is expected rather than a failure of the strategy: buy-and-hold is very hard to beat on a single asset in a sustained uptrend, since any time spent in cash means missed gains. Evaluating trend-following fairly requires testing across other regimes (declining, sideways, or high-volatility markets), which is the next phase of analysis.

# %%
print("crossover peak equity:", mac["Equity"].max())
print("crossover peak date:", mac.loc[mac["Equity"].idxmax(), "Date"])
print("crossover equity on 2019-06-03:", mac.loc[mac["Date"]=="2019-06-03", "Equity"].values)
print("buy & hold peak equity:", bh["Equity"].max())
print("buy & hold peak date:", bh.loc[bh["Equity"].idxmax(), "Date"])
print("buy & hold equity on 2019-06-03:", bh.loc[bh["Date"]=="2019-06-03", "Equity"].values)

print("----------------------------------------------------------")
print("crossover running peak on 2019-06-03:",
      mac.loc[mac["Date"]=="2019-06-03"].index[0])
peak_so_far = mac.loc[:mac.loc[mac["Date"]=="2019-06-03"].index[0], "Equity"].max()
print("running peak up to 2019-06-03:", peak_so_far)
print("equity there:", 123004.61)
print("correct drawdown:", (123004.61 - peak_so_far) / peak_so_far)
# Out:
# crossover peak equity: 527995.86239
# crossover peak date: 2022-01-03
# crossover equity on 2019-06-03: [123004.609055]
# buy & hold peak equity: 1063860.587902
# buy & hold peak date: 2024-12-26
# buy & hold equity on 2019-06-03: [171348.825739]
# ----------------------------------------------------------
# crossover running peak on 2019-06-03: 1110
# running peak up to 2019-06-03: 226164.653075
# equity there: 123004.61
# correct drawdown: -0.4561280539306485

# %%
btc_bh = pd.read_csv("../output/BTC-USD_BuyAndHold.csv")
btc_mac = pd.read_csv("../output/BTC-USD_crossover_50_200.csv")

cumMaxHoldBTC = btc_bh["Equity"].cummax()
cumMaxCrossBTC = btc_mac["Equity"].cummax()

ddHoldBTC  = (btc_bh["Equity"]  - cumMaxHoldBTC)  / cumMaxHoldBTC
ddCrossBTC = (btc_mac["Equity"] - cumMaxCrossBTC) / cumMaxCrossBTC

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=btc_bh["Date"],  y=ddHoldBTC * 100,  name="Buy & Hold"))
fig.add_trace(go.Scatter(x=btc_mac["Date"], y=ddCrossBTC * 100, name="MA Crossover"))
fig.update_layout(title="BTC: Drawdown Over Time",
                  xaxis_title="Date", yaxis_title="Drawdown (%)")
fig.show()
